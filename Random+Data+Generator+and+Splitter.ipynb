# %%
# Messing with random data generation
# splitting into smaller data set for exploration
# Plotting Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


N = 1000
mean = (1, 2)
cov = [[1,0], [0,1]]
data = np.random.multivariate_normal(mean, cov, N)

# %%
data
# Out:
# array([[ 2.03865965,  1.31528819],
#        [ 1.35470247,  1.6863737 ],
#        [ 0.22368127,  3.35510391],
#        ...,
#        [ 0.4854751 ,  1.40547543],
#        [ 0.45744515,  3.0401709 ],
#        [-0.09536166,  2.69880155]])

# %%
df = pd.DataFrame(data)
df.columns = ['a','b']

# %%
df1 = df.sample(frac=0.1, replace=True)
df1
# Out:
#             a         b
# 823  2.755504  0.512120
# 516 -0.056812  0.991137
# 983 -0.172116  2.108996
# 369 -0.383303  0.270073
# 44   1.810642  2.069395
# 817  1.390910  2.723947
# 55  -0.333698  0.224812
# 185  1.028339  1.256280
# 139  0.949187  1.286782
# 484 -0.553502  1.767166
# 408  0.522242  3.315881
# 517  1.107883  1.082071
# 678  0.411544  3.327153
# 192  0.755131  3.298642
# 806  0.648827  2.842020
# 803  1.756252  2.863696
# 461 -1.658906  1.638035
# 145 -0.375636  2.488721
# 908  2.074982  2.301717
# 208  1.018921  2.951443
# 655  1.963421  1.565092
# 950  2.621612  1.987783
# 388  0.253783  2.423354
# 617  2.164198  2.251476
# 3    0.116578  1.521714
# 359  0.762033  2.769737
# 296  0.388198  4.207206
# 67   1.766738  3.073523
# 327  2.560627 -0.163292
# 197  1.660537  2.629366
# ..        ...       ...
# 98   0.536004  2.428422
# 658  1.187113  3.195705
# 623  1.989049  3.475440
# 117 -0.589560  1.714247
# 463  2.091131  2.534532
# 521  1.336796  2.813398
# 326  0.043532  3.430173
# 805  2.585826  4.536077
# 537  2.417110  1.899869
# 340  0.638559  0.793021
# 46   1.190115  1.690423
# 451  1.645687  0.947368
# 890 -0.151330  1.893054
# 329  3.148384  2.391729
# 243  0.358683  1.171800
# 849  1.571001  4.250515
# 547  3.091391  2.026774
# 543  0.231985  2.283378
# 878  2.344964  3.690211
# 341  2.825626  1.540457
# 416  1.175584  2.501893
# 554  2.495026  2.694456
# 91   2.894124  0.706496
# 740  0.709974  2.806743
# 746  1.751512  2.015487
# 514 -0.055883  1.877842
# 602  2.238412  2.573851
# 536  1.748828  3.988029
# 374  2.628016  2.279528
# 202  2.132145  1.062853
#
# [100 rows x 2 columns]

# %%
x = df1['a']
y = df1['b']

plt.scatter(x,y)

plt.show()

# %%
N = 50

x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = np.pi * (15 * np.random.rand(N))**2  # 0 to 15 point radii

plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.show()

# %%
# Mission Accomplished
